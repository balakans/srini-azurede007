-- %%
/*
drop table inceptez_catalog.outputdb.tblstatesalesdata;

Create table if not exists inceptez_catalog.outputdb.tblstatesalesdata
as
select state, round(sum(amount),2) as sales,current_date as load_dt
from inceptez_catalog.inputdb.tbltxns 
group by state;

*/
insert into inceptez_catalog.outputdb.tblstatesalesdata 

select state, sum(amount) as sales,current_date as load_dt
from inceptez_catalog.inputdb.tbltxns 
group by state;
