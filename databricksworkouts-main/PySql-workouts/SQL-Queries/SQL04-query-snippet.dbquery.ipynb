-- %%
select *
from inceptez_catalog.inputdb.tbltxns where state in ('California','Texas') and amount > 100;

select * from  inceptez_catalog.inputdb.tbltxns where state = 'Texas' and amount > 100;

select txnid,amount,city,state,paytype from inceptez_catalog.inputdb.tbltxns where state = 'Texas' and amount > 100;
